# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_excel('iris - train.xlsx')  # Replace with your actual CSV file path

# %%
data.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
X = data.iloc[:, :-1]  # All columns except the last as features

# %%
X
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
y = data.iloc[:, -1]   # Last column as label

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
model = RandomForestClassifier()
model.fit(X.values, y.values)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict([[6.3 ,	2.9 ,	5.6	, 1.8
                             ]])  # Predict on the same/new data (for demonstration)

# %%
predictions
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
data2 = pd.read_excel('iris - test.xlsx')

# %%
data2
# Out:
#     sepallength  sepalwidth  petallength  petalwidth           class
# 0           6.3         2.9          5.6         1.8  Iris-virginica
# 1           6.5         3.0          5.8         2.2  Iris-virginica
# 2           7.6         3.0          6.6         2.1  Iris-virginica
# 3           4.9         2.5          4.5         1.7  Iris-virginica
# 4           7.3         2.9          6.3         1.8  Iris-virginica
# 5           6.7         2.5          5.8         1.8  Iris-virginica
# 6           7.2         3.6          6.1         2.5  Iris-virginica
# 7           6.5         3.2          5.1         2.0  Iris-virginica
# 8           6.4         2.7          5.3         1.9  Iris-virginica
# 9           6.8         3.0          5.5         2.1  Iris-virginica
# 10          5.7         2.5          5.0         2.0  Iris-virginica
# 11          5.8         2.8          5.1         2.4  Iris-virginica
# 12          6.4         3.2          5.3         2.3  Iris-virginica
# 13          6.5         3.0          5.5         1.8  Iris-virginica
# 14          7.7         3.8          6.7         2.2  Iris-virginica
# 15          7.7         2.6          6.9         2.3  Iris-virginica
# 16          6.0         2.2          5.0         1.5  Iris-virginica
# 17          6.9         3.2          5.7         2.3  Iris-virginica
# 18          5.6         2.8          4.9         2.0  Iris-virginica
# 19          7.7         2.8          6.7         2.0  Iris-virginica
# 20          6.3         2.7          4.9         1.8  Iris-virginica
# 21          6.7         3.3          5.7         2.1  Iris-virginica
# 22          7.2         3.2          6.0         1.8  Iris-virginica
# 23          6.2         2.8          4.8         1.8  Iris-virginica
# 24          6.1         3.0          4.9         1.8  Iris-virginica
# 25          6.4         2.8          5.6         2.1  Iris-virginica
# 26          7.2         3.0          5.8         1.6  Iris-virginica
# 27          7.4         2.8          6.1         1.9  Iris-virginica
# 28          7.9         3.8          6.4         2.0  Iris-virginica
# 29          6.4         2.8          5.6         2.2  Iris-virginica
# 30          6.3         2.8          5.1         1.5  Iris-virginica
# 31          6.1         2.6          5.6         1.4  Iris-virginica
# 32          7.7         3.0          6.1         2.3  Iris-virginica
# 33          6.3         3.4          5.6         2.4  Iris-virginica

# %%
X_test = data2.iloc[:, : -1]

# %%
predictions = model.predict(X_test.values)

# %%
predictions
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica'], dtype=object)
